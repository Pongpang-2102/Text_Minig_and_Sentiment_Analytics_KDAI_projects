# %% [markdown]
# <a href="https://colab.research.google.com/github/Pongpang-2102/Text_Mining_and_Sentiment_Analytics_KDAI_projects/blob/main/KDAI_Tutorial_TMSA_bs_pantip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4
# !pip install requests
# !pip install lxml
# !pip install html5lib
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.3)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib) (0.5.1)

# %%
#นำเข้าไลบรารี
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re

# %%
#กำหนด URL ที่ต้องการดึงข้อมูล
url = 'https://pantip.com/tag/อีวานเกเลียน'
response = requests.get(url)

# %%
#ใช้ BeautifulSoup ดึง HTML content
page_html = BeautifulSoup(response.content, 'html.parser')

# %%
print(page_html.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="th">
#  <head>
#   <link href="https://pantip.com/fav-icon.ico" rel="icon" type="image/x-icon"/>
#   <meta charset="utf-8"/>
#   <meta content="UaiArydZb5Bi28s5YgunZNSoObqXV97zA_OYbSuXAE8" name="google-site-verification"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link as="font" crossorigin="anonymous" href="/static/fonts/material-design-icons/MaterialIcons-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link href="/static/v1.30/main.min.css" rel="stylesheet" type="text/css"/>
#   <script>
#    (function(w,d,s,l,i){w[l] = w[l] || []; w[l].push({'gtm.start':
#                     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                     })(window,document,'script','dataLayer','GTM-NJ2J94K');
#   </script>
#   <script>
#    (function(w,d,s,i,c){var f=d.createElement(s);f.type="text/javascript";f.async=true;
#                     f.src=("https:"==d.location.protocol? "https://ssl-avd.innity.net":"http://avd.innity.net")+
#                     "/"+i+"/container_"+c+".js";var g=d.getElementsByTagName(s)[0];g.parentNode.insertBefore(f, g);})
#                     (window, document, "script", "254", "57e4d9521c51b1315c101158");
#   </script>
#   <script async="" src="https://media.innity.net/lib/innityPrebidHB.js" type="text/javascript">
#   </script>
#   <script async="" src="https://media.innity.net/adnetwork/hb_prebid/1358/hbconfig_prebid134.js" type="text/javascript">
#   </script>
#   <title>
#    อีวานเกเลียน - Pantip
#   </title>
#   <meta content="อีวานเกเลียน ถูกพูดถึงอย่างไรบน Pantip อ่านกระทู้ อีวานเกเลียน ตั้งกระทู้และร่วมพูดคุยเกี่ยวกับ อีวานเกเลียน" name="description"/>
#   <link href="https://pantip.com/tag/อีวานเกเลียน" rel="canonical"/>
#   <meta content="อีวานเกเลียน - Pantip" name="twitter:title"/>
#   <meta content="อีวานเกเลียน ถูกพูดถึงอย่างไรบน Pantip อ่านกระทู้ อีวานเกเลียน ตั้งกระทู้และร่วมพูดคุยเกี่ยวกับ อีวานเกเลียน" name="twitter:description"/>
#   <meta content="https://ptcdn.info/pantip/pantip_share_content.png" name="twitter:image"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@Pantip1996" name="twitter:site"/>
#   <meta content="@Pantip1996" name="twitter:creator"/>
#   <meta content="pantip.com" name="twitter:domain"/>
#   <meta content="https://pantip.com/tag/อีวานเกเลียน" name="twitter:url"/>
#   <meta content="อีวานเกเลียน - Pantip" property="og:title"/>
#   <meta content="อีวานเกเลียน ถูกพูดถึงอย่างไรบน Pantip อ่านกระทู้ อีวานเกเลียน ตั้งกระทู้และร่วมพูดคุยเกี่ยวกับ อีวานเกเลียน" property="og:description"/>
#   <meta content="https://pantip.com/tag/อีวานเกเลียน" property="og:url"/>
#   <meta content="Pantip" property="og:site_name"/>
#   <meta content="https://ptcdn.info/pantip/pantip_share_content.png" property="og:image"/>
#   <meta content="article" property="og:type"/>
#   <meta content="117368861736328" property="fb:app_id"/>
#   <meta content="https://www.facebook.com/pantipdotcom" property="article:author"/>
#   <meta content="https://www.facebook.com/pantipdotcom" property="article:publisher"/>
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script>
#    if (screen.width <= 992) {
#                                 window.googletag = window.googletag || {cmd: []}
#                                 googletag.cmd.push(function() {
#                                     googletag.pubads().disableInitialLoad()
#                                     googletag.defineSlot('/5363867/Tabloid_Tag_Mobile', [[1, 1], [300, 250]], 'div-gpt-ad-1598512055453-0').addService(googletag.pubads())
#                                     googletag.pubads().enableSingleRequest();
#                                     googletag.pubads().collapseEmptyDivs();
#                                     googletag.enableServices();
#                                 })
#                             }
#   </script>
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script>
#    if (screen.width <= 992) {
#                                 window.googletag = window.googletag || {cmd: []}
#                                 googletag.cmd.push(function() {
#                                     googletag.pubads().disableInitialLoad()
#                                     googletag.defineSlot('/5363867/Billboard_Tag_Mobile', [[1, 1], [300, 250]], 'div-gpt-ad-1598512119439-0').addService(googletag.pubads())
#                                     googletag.pubads().enableSingleRequest();
#                                     googletag.pubads().collapseEmptyDivs();
#                                     googletag.enableServices();
#                                 })
#                             }
#   </script>
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script>
#    window.googletag = window.googletag || {cmd: []}
#   							googletag.cmd.push(function() {
# 								googletag.pubads().disableInitialLoad()
#     							googletag.defineSlot('/5363867/Tag_Forum_300x250', [300, 250], 'div-gpt-ad-1569929697239-0').addService(googletag.pubads())
#     							googletag.pubads().enableSingleRequest();
#     							googletag.pubads().collapseEmptyDivs();
#     							googletag.enableServices();
#   							})
#   </script>
#   <meta content="20" name="next-head-count"/>
#   <link as="style" href="/_next/static/css/480672f85bab45b8.css" rel="preload"/>
#   <link data-n-g="" href="/_next/static/css/480672f85bab45b8.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/webpack-2dfdae1d29e2a5f0.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/framework-334d6aa39a4817ea.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/main-ce4e9d4380103aef.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/_app-ad0ee5c7056b8a53.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/tag-f5449994aa65f0a7.js">
#   </script>
#   <script defer="" src="/_next/static/ABF8ysW8mQmD6nqO7iHMq/_buildManifest.js">
#   </script>
#   <script defer="" src="/_next/static/ABF8ysW8mQmD6nqO7iHMq/_ssgManifest.js">
#   </script>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div>
#     <div>
#      <noscript>
#       <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NJ2J94K" style="display:none;visibility:hidden" width="0">
#       </iframe>
#      </noscript>
#      <div class="pt-body with-footer with-nav">
#       <div class="pt-doodle" style="background:url(https://ptcdn.info/doodle/2023/5d07273900d01f33da0f618c_yii66wxtur.png), url(https://ptcdn.info/doodle/2023/5d07273900d01f33da0f618c_tcz28qzvon.png);background-size:auto, cover;background-position:center, bottom;background-repeat:no-repeat, repeat" title="Pantip.com">
#        <div id="pantipHeader">
#         <div class="pt-nav-bar">
#          <ul class="pt-left">
#           <a href="https://pantip.com/">
#            <li class="pt-xl_nav" style="width:82px">
#             <span class="pt-stickyLogo">
#              หน้าแรก
#             </span>
#             <img alt="pantip-logo" class="pt-stickyLogo" src="https://ptcdn.info/mobile/logo-mobile-pantip-white.png" style="display:none"/>
#            </li>
#           </a>
#           <li class="pt-xl_nav">
#            คอมมูนิตี้
#            <i class="material-icons icon-va-6 m-l-4 m-r-de8">
#             arrow_drop_down
#            </i>
#           </li>
#           <a href="https://pantip.com/activities">
#            <li class="pt-xl_nav">
#             กิจกรรม
#            </li>
#           </a>
#           <a href="https://pantip.com/point">
#            <li class="pt-xl_nav">
#             <span class="pt-block-relative">
#              <span>
#               แลกพอยต์
#              </span>
#             </span>
#            </li>
#           </a>
#           <li class="pt-xl_nav">
#            อื่นๆ
#            <i class="material-icons icon-va-6 m-l-4 m-r-de8">
#             arrow_drop_down
#            </i>
#           </li>
#           <li class="pt-md_nav">
#            <a href="https://pantip.com/" title="pantip.com">
#             <img alt="pantip-logo" src="https://ptcdn.info/mobile/logo-mobile-pantip-white.png"/>
#            </a>
#           </li>
#          </ul>
#          <div class="pt-search-nav" data-type="f">
#           <input autocomplete="off" class="search-box" id="search-box" maxlength="256" placeholder="" type="text" value=""/>
#           <i class="material-icons md-18 icon-va-6">
#            search
#           </i>
#           <div>
#           </div>
#          </div>
#          <ul class="pt-right-nav">
#           <a href="https://pantip.com/forum/new_topic">
#            <li class="pt-xl_nav pt-nav-topic">
#             <i class="pantip-icons pt-ic-add_post icon-va-8 m-r-8 icolor-primary">
#             </i>
#             <span>
#              ตั้งกระทู้
#             </span>
#            </li>
#           </a>
#           <a role="button">
#            <li class="pt-xl_nav pt-nav-login">
#             <i class="pt-lists-item__graphic material-icons icon-va-8 txt-primary">
#              account_circle
#             </i>
#             <span>
#              เข้าสู่ระบบ / สมัครสมาชิก
#             </span>
#            </li>
#           </a>
#           <a href="https://pantip.com/forum/new_topic">
#            <li class="pt-md_nav">
#             <i class="pantip-icons pt-ic-add_post icon-va-8 icolor-primary">
#             </i>
#            </li>
#           </a>
#           <a role="button">
#            <li class="pt-top-nav-communities pt-md_nav">
#             <span class="icolor-primary pantip-icons pt-top-nav-communities pt-ic-pantip_communities">
#             </span>
#            </li>
#           </a>
#           <a role="button">
#            <li class="pt-md_nav">
#             <i class="material-icons icon-va-8">
#              menu
#             </i>
#            </li>
#           </a>
#           <a>
#            <li class="pt-sm_nav">
#             <i class="material-icons icon-va-8">
#              search
#             </i>
#            </li>
#           </a>
#           <a href="https://pantip.com/forum/new_topic">
#            <li class="pt-sm_nav">
#             <i class="pantip-icons pt-ic-add_post icon-va-8 icolor-primary">
#             </i>
#            </li>
#           </a>
#           <a href="https://pantip.com/communities/forum">
#            <li class="pt-top-nav-communities pt-sm_nav">
#             <span class="pt-top-nav-communities icolor-primary pantip-icons pt-ic-pantip_communities">
#             </span>
#            </li>
#           </a>
#           <a role="button">
#            <li class="pt-sm_nav">
#             <i class="material-icons icon-va-8">
#              menu
#             </i>
#            </li>
#           </a>
#          </ul>
#         </div>
#         <div class="pt-modal-withnav pt-xl-toggle-hide" id="ptModalwithCommunity">
#         </div>
#         <div class="pt-wrapper-mobile_fulid bg-purple-pantip-600 pt-sm-toggle-hide" style="display:none !important">
#          <div class="pt-mobile__search">
#           <ul class="pt-left__nav">
#            <li>
#             <i class="material-icons icon-va-8">
#              arrow_back
#             </i>
#            </li>
#           </ul>
#           <div class="pt-search-nav m-r-16 m-l-16">
#            <input autocomplete="off" class="search-box" maxlength="256" placeholder="" style="font-size:16px" type="text" value=""/>
#            <i class="material-icons md-18 icon-va-4">
#             search
#            </i>
#           </div>
#          </div>
#          <div class="pt-search_result">
#           <div class="m-b-20">
#            <div>
#             <ul class="pt-lists pt-lists--avatar-list pt-lists-count__search">
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="pt-md-toggle-hide pt-modal-withnav" id="ptModalwithNav">
#       </div>
#       <div class="pt-md-toggle-hide pt-wrapper-sidenav" id="ptSidebar">
#        <div class="pt-sidenav">
#         <ul class="pt-lists">
#          <li class="pt-lists-item">
#           <a style="cursor:pointer" target="_blank">
#            <span class="pt-lists-item__graphic material-icons">
#             account_circle
#            </span>
#            <span class="pt-lists-item__text">
#             เข้าสู่ระบบ / สมัครสมาชิก
#            </span>
#           </a>
#          </li>
#          <li class="pt-lists-item__divider">
#          </li>
#          <li class="pt-lists-item">
#           <a href="https://pantip.com/point" style="cursor:pointer" target="_blank">
#            <span class="pt-lists-item__graphic pantip-icons pt-ic-stars-black-outline">
#            </span>
#            <span class="pt-lists-item__text">
#             แลกพอยต์
#            </span>
#           </a>
#          </li>
#          <li class="pt-lists-item">
#           <a href="https://pantip.com/activities" style="cursor:pointer" target="_blank">
#            <span class="pt-lists-item__graphic pantip-icons pt-ic-event">
#            </span>
#            <span class="pt-lists-item__text">
#             กิจกรรมพันทิป
#            </span>
#           </a>
#          </li>
#          <li class="pt-lists-item__divider">
#          </li>
#          <ul class="pt-lists_style-none caption m-all-16 p-l-8">
#           <li>
#            <a class="txt-secondary" href="https://pantip.com/about/tos">
#             กฎ กติกาและมารยาท
#            </a>
#           </li>
#           <li>
#            <a class="txt-secondary" href="https://pantip.com/about/defamation">
#             คำแนะนำการโพสต์
#            </a>
#           </li>
#           <li>
#            <a class="txt-secondary" href="https://pantip.com/about/privacy">
#             นโยบายเกี่ยวกับข้อมูลส่วนบุคคล
#            </a>
#           </li>
#           <li>
#            <a class="txt-secondary" href="https://pantip.com/about/privilege">
#             สิทธิ์การใช้งานของสมาชิก
#            </a>
#           </li>
#           <li>
#            <a class="txt-secondary" href="https://pantip.com/about/contact">
#             ติดต่อทีมงาน Pantip
#            </a>
#           </li>
#           <li>
#            <a class="txt-secondary" href="https://pantip.com/advertising">
#             ติดต่อลงโฆษณา
#            </a>
#           </li>
#           <li>
#            <a class="txt-secondary" href="https://pantip.com/about/job">
#             ร่วมงานกับ Pantip
#            </a>
#           </li>
#           <li>
#            <a class="txt-secondary" href="https://pantip.com/app">
#             Download App Pantip
#            </a>
#           </li>
#           <li>
#            <a class="txt-secondary" href="https://pantip.com/about/certified_developer">
#             Pantip Certified Developer
#            </a>
#           </li>
#          </ul>
#         </ul>
#         <div class="p-tnb-32">
#         </div>
#         <div class="pt-sidenav-social">
#          <span class="caption txt-secondary m-r-auto p-r-12">
#           ติดตาม
#          </span>
#          <a href="https://www.facebook.com/pantipdotcom/" rel="noopener noreferrer" target="_blank" title="pantip.com">
#           <i class="pantip-icons pt-ic-facebook icolor-secondary m-r-8">
#           </i>
#          </a>
#          <a href="https://twitter.com/Pantip1996" rel="noopener noreferrer" target="_blank" title="@Pantip1996">
#           <i class="pantip-icons pt-ic-twitter icolor-secondary m-r-8">
#           </i>
#          </a>
#          <a href="https://www.youtube.com/@pantipchannel" rel="noopener noreferrer" target="_blank" title="pantip1996">
#           <i class="pantip-icons pt-ic-youtube icolor-secondary m-r-8">
#           </i>
#          </a>
#          <a href="https://www.instagram.com/pantipdotcom" rel="noopener noreferrer" target="_blank" title="@pantipdotcom">
#           <i class="pantip-icons pt-ic-instragram icolor-secondary m-r-8">
#           </i>
#          </a>
#          <a href="https://www.tiktok.com/@pantip1996" rel="noopener noreferrer" target="_blank" title="@pantip1996">
#           <i class="pantip-icons pt-ic-tiktok icolor-secondary">
#           </i>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div>
#        <div class="pt-block-location m-b-20">
#         <div class="container pt-beta-container">
#          <nav>
#           <div class="pt-breadcrumb">
#            <a href="https://pantip.com/communities/tag">
#             แท็ก
#            </a>
#            <a href="https://pantip.com/tag/อีวานเกเลียน">
#             อีวานเกเลียน
#            </a>
#           </div>
#          </nav>
#         </div>
#        </div>
#       </div>
#       <div class="container">
#        <div class="row">
#         <div class="col-12">
#          <div class="pt-block pt-block-purple-3 m-b-20">
#           <div class="pt-tagging p-all-16">
#            <h3>
#             อีวานเกเลียน
#            </h3>
#            <div class="row">
#             <div class="col-sm-auto col-9 text-nowrap">
#              <span>
#               397
#               <!-- -->
#               กระทู้
#              </span>
#              <span>
#               15
#               <!-- -->
#               ผู้ติดตาม
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="ads_box_type1 m-b-20" id="second-tag-ads-mobile-tabloid" style="display:none">
#         <div id="div-gpt-ad-1598512055453-0" style="width:300px;height:250px">
#          <script>
#           if (screen.width <= 992) {
#                                     googletag.cmd.push(function() {
#                                         googletag.display('div-gpt-ad-1598512055453-0')
#                                         googletag.pubads().addEventListener('slotRenderEnded', (event) => {
#                                             if (!event.isEmpty) {
#                                                 document.getElementById('second-tag-ads-mobile-tabloid').style.display = null
#                                             }
#                                         })
#                                     })
#                                 } else {
#                                     document.getElementById('second-tag-ads-mobile-tabloid').style.display = 'none'
#                                 }
#          </script>
#         </div>
#        </div>
#        <div class="pt-block pt-block-purple-2 m-b-20">
#         <div class="pt-block-header pt-block-header-purple-1 flex-column">
#          <div class="h6 m-r-12 txt-yellow-700">
#           Pantip Trend
#          </div>
#         </div>
#         <div class="pt-loader-list">
#          <div class="pt-loader-image pt-loader">
#          </div>
#          <div class="pt-loader-list-text">
#           <div class="pt-loader-text pt-loader">
#           </div>
#           <div class="pt-loader-text pt-loader">
#           </div>
#          </div>
#          <div class="pt-loader-text last-text pt-loader">
#          </div>
#         </div>
#         <div class="pt-loader-list">
#          <div class="pt-loader-image pt-loader">
#          </div>
#          <div class="pt-loader-list-text">
#           <div class="pt-loader-text pt-loader">
#           </div>
#           <div class="pt-loader-text pt-loader">
#           </div>
#          </div>
#          <div class="pt-loader-text last-text pt-loader">
#          </div>
#         </div>
#         <div class="pt-loader-list">
#          <div class="pt-loader-image pt-loader">
#          </div>
#          <div class="pt-loader-list-text">
#           <div class="pt-loader-text pt-loader">
#           </div>
#           <div class="pt-loader-text pt-loader">
#           </div>
#          </div>
#          <div class="pt-loader-text last-text pt-loader">
#          </div>
#         </div>
#         <div class="pt-loader-list">
#          <div class="pt-loader-image pt-loader">
#          </div>
#          <div class="pt-loader-list-text">
#           <div class="pt-loader-text pt-loader">
#           </div>
#           <div class="pt-loader-text pt-loader">
#           </div>
#          </div>
#          <div class="pt-loader-text last-text pt-loader">
#          </div>
#         </div>
#         <div class="pt-loader-list">
#          <div class="pt-loader-image pt-loader">
#          </div>
#          <div class="pt-loader-list-text">
#           <div class="pt-loader-text pt-loader">
#           </div>
#           <div class="pt-loader-text pt-loader">
#           </div>
#          </div>
#          <div class="pt-loader-text last-text pt-loader">
#          </div>
#         </div>
#        </div>
#        <div class="ads_box_type1 m-b-20" id="second-tag-ads-mobile-billboard" style="display:none">
#         <div id="div-gpt-ad-1598512119439-0" style="width:300px;height:250px">
#          <script>
#           if (screen.width <= 992) {
#                                     googletag.cmd.push(function() {
#                                         googletag.display('div-gpt-ad-1598512119439-0')
#                                         googletag.pubads().addEventListener('slotRenderEnded', (event) => {
#                                             if (!event.isEmpty) {
#                                                 document.getElementById('second-tag-ads-mobile-billboard').style.display = null
#                                             }
#                                         })
#                                     })
#                                 } else {
#                                     document.getElementById('second-tag-ads-mobile-billboard').style.display = 'none'
#                                 }
#          </script>
#         </div>
#        </div>
#        <div class="row">
#         <div class="col-lg-8">
#          <div class="pt-block pt-block-purple-2 m-b-20" id="pt-topic-left">
#           <div id="pt-list-header_01_outer">
#            <div id="pt-list-header_01_inner">
#             <div class="pt-block-header pt-block-header-purple-1 flex-column">
#              <div class="h6 m-r-12 txt-yellow-700">
#               กระทู้ล่าสุด
#              </div>
#             </div>
#             <div id="newsfeed-nav-menu-outer">
#              <div id="newsfeed-nav-menu-inner">
#               <div class="row m-all-0 pt-block-filter pt-block-relative">
#                <div class="col-sm-8 col-12 p-lnr-0 flexbox align-items-center m-filter">
#                 <div class="subtitle-1 pt-block-hide" id="pt-filter-header">
#                  เลือกประเภทกระทู้
#                 </div>
#                 <div class="pt-list-sub-filter pt-overflow" id="pt-sub-filter">
#                  <div class="select-now">
#                   <a class="gtm-topic-type-filter" data-type="0" style="cursor:pointer">
#                    กระทู้ทั้งหมด
#                   </a>
#                  </div>
#                  <div class="pt-block-relative">
#                   <a class="gtm-topic-type-filter" data-type="7" style="cursor:pointer">
#                    คลังกระทู้โปรด
#                    <i class="pt-nav__link-badge">
#                    </i>
#                   </a>
#                  </div>
#                  <div class="">
#                   <a class="gtm-topic-type-filter" data-type="3" style="cursor:pointer">
#                    ถามตอบ
#                   </a>
#                  </div>
#                  <div class="">
#                   <a class="gtm-topic-type-filter" data-type="1" style="cursor:pointer">
#                    พูดคุย
#                   </a>
#                  </div>
#                  <div class="">
#                   <a class="gtm-topic-type-filter" data-type="4" style="cursor:pointer">
#                    รีวิว
#                   </a>
#                  </div>
#                  <div class="">
#                   <a class="gtm-topic-type-filter" data-type="2" style="cursor:pointer">
#                    โพล
#                   </a>
#                  </div>
#                  <div class="">
#                   <a class="gtm-topic-type-filter" data-type="5" style="cursor:pointer">
#                    ข่าว
#                   </a>
#                  </div>
#                  <div class="">
#                   <a class="gtm-topic-type-filter" data-type="6" style="cursor:pointer">
#                    ซื้อขาย
#                   </a>
#                  </div>
#                 </div>
#                </div>
#                <div class="pt-explian-filter">
#                 <i class="material-icons m-l-4 pt-select-none" id="pt-toggle-arrow" style="cursor:pointer">
#                  
#                 </i>
#                 <i class="filter-icon material-icons m-l-4 pt-select-none gtm-topic-layout filter-inactive filter-next" data-header-class="pt-list__type-c" data-id="1" data-list-class="gtm-topic-layout-headline" id="gtm-topic-layout-headline" style="cursor:pointer" title="แบบหัวข้อ">
#                  
#                 </i>
#                 <i class="filter-icon material-icons m-l-4 pt-select-none gtm-topic-layout filter-current" data-header-class="pt-list__type-a" data-id="2" data-list-class="gtm-topic-layout-compact" id="gtm-topic-layout-compact" style="cursor:pointer" title="แบบรายการ">
#                  
#                 </i>
#                </div>
#               </div>
#               <div class="row m-all-0 pt-block-filter pt-block-hide" id="m-filter">
#                <button class="btn btn-sm m-all-6 btn-primary" data-type="0" type="button">
#                 กระทู้ทั้งหมด
#                </button>
#                <button class="btn btn-sm m-all-6 btn-secondary" data-type="7" type="button">
#                 คลังกระทู้โปรด
#                </button>
#                <button class="btn btn-sm m-all-6 btn-secondary" data-type="3" type="button">
#                 ถามตอบ
#                </button>
#                <button class="btn btn-sm m-all-6 btn-secondary" data-type="1" type="button">
#                 พูดคุย
#                </button>
#                <button class="btn btn-sm m-all-6 btn-secondary" data-type="4" type="button">
#                 รีวิว
#                </button>
#                <button class="btn btn-sm m-all-6 btn-secondary" data-type="2" type="button">
#                 โพล
#                </button>
#                <button class="btn btn-sm m-all-6 btn-secondary" data-type="5" type="button">
#                 ข่าว
#                </button>
#                <button class="btn btn-sm m-all-6 btn-secondary" data-type="6" type="button">
#                 ซื้อขาย
#                </button>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div>
#            <ul class="pt-list pt-list-item__full-title pt-list__type-a">
#             <li class="pt-list-item pt-list-item__no-img">
#              <div class="pt-list-item__title">
#               <h2>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/42003778" target="_blank">
#                 <i class="pantip-icons md-18 pt-ic-topic_type_question">
#                 </i>
#                 อยากรู้ว่าทำไมชินจิกับอาซึกะถึงใส่ห่วงคอสีดำหรอคะ ?
#                </a>
#               </h2>
#               <span>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/42003778">
#                </a>
#               </span>
#               <div class="pt-list-item__tag">
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">
#                 อีวานเกเลียน
#                </a>
#               </div>
#              </div>
#              <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/42003778" target="_blank">
#               <div class="pt-list-item__img img-thumbnail lazyload" data-bg="">
#               </div>
#              </a>
#              <div class="pt-list-item__info">
#               <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/6739096" target="_blank">
#                <div class="img-thumbnail img-circle" style="background-image:url(https://ptcdn.info/images/avatar_member_default.png)">
#                </div>
#               </a>
#               <h5>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/6739096" target="_blank">
#                 สมาชิกหมายเลข 6739096
#                </a>
#               </h5>
#               <span title="7 พฤษภาคม 2566 เวลา 20:12 น.">
#                7 พ.ค.
#               </span>
#              </div>
#              <div class="pt-list-item__stats">
#               <span class="pt-li_stats-comment">
#                <i class="material-icons md-18">
#                 message
#                </i>
#                0
#               </span>
#               <span class="pt-li_stats-vote">
#                <i class="material-icons md-18">
#                 add_box
#                </i>
#                0
#               </span>
#              </div>
#             </li>
#             <li class="pt-list-item pt-list-item__no-img">
#              <div class="pt-list-item__title">
#               <h2>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41960388" target="_blank">
#                 <i class="pantip-icons md-18 pt-ic-topic_type_question">
#                 </i>
#                 สรุปแล้วคุณมิซาโตะตายจริงหรอครับ?
#                </a>
#               </h2>
#               <span>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41960388">
#                </a>
#               </span>
#               <div class="pt-list-item__tag">
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">
#                 อีวานเกเลียน
#                </a>
#               </div>
#              </div>
#              <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41960388" target="_blank">
#               <div class="pt-list-item__img img-thumbnail lazyload" data-bg="">
#               </div>
#              </a>
#              <div class="pt-list-item__info">
#               <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/7503951" target="_blank">
#                <div class="img-thumbnail img-circle" style="background-image:url(https://ptcdn.info/images/avatar_member_default.png)">
#                </div>
#               </a>
#               <h5>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/7503951" target="_blank">
#                 สมาชิกหมายเลข 7503951
#                </a>
#               </h5>
#               <span title="10 เมษายน 2566 เวลา 23:01 น.">
#                10 เม.ย.
#               </span>
#              </div>
#              <div class="pt-list-item__stats">
#               <span class="pt-li_stats-comment">
#                <i class="material-icons md-18">
#                 message
#                </i>
#                0
#               </span>
#               <span class="pt-li_stats-vote">
#                <i class="material-icons md-18">
#                 add_box
#                </i>
#                0
#               </span>
#              </div>
#             </li>
#             <li class="pt-list-item">
#              <div class="pt-list-item__title">
#               <h2>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41909027" target="_blank">
#                 <i class="pantip-icons md-18 pt-ic-topic_type_talking">
#                 </i>
#                 [SPOIL] • Evangelion:3.0 (-46h) YOU CAN (NOT) REDO.
#                </a>
#               </h2>
#               <span>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41909027">
#                </a>
#               </span>
#               <div class="pt-list-item__tag">
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อนิเมะ" target="_blank">
#                 อนิเมะ
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/การ์ตูนญี่ปุ่น" target="_blank">
#                 การ์ตูนญี่ปุ่น
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/Evangelion:_3.0_You_Can_(Not)_Redo" target="_blank">
#                 Evangelion: 3.0 You Can (Not) Redo
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">
#                 อีวานเกเลียน
#                </a>
#               </div>
#              </div>
#              <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41909027" target="_blank">
#               <div class="pt-list-item__img img-thumbnail lazyload" data-bg="https://f.ptcdn.info/053/080/000/rrbhz64uqqg55DhKq9d9-s.jpg">
#               </div>
#              </a>
#              <div class="pt-list-item__info">
#               <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/3535250" target="_blank">
#                <div class="img-thumbnail img-circle" style="background-image:url(https://p.ptcdn.info/606/014/000/3535250_26336165161665665436_IMG-0330-JPG_m.jpg)">
#                </div>
#               </a>
#               <h5>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/3535250" target="_blank">
#                 Guillotine Cutter
#                </a>
#               </h5>
#               <span title="11 มีนาคม 2566 เวลา 01:40 น.">
#                11 มี.ค.
#               </span>
#              </div>
#              <div class="pt-list-item__stats">
#               <span class="pt-li_stats-comment">
#                <i class="material-icons md-18">
#                 message
#                </i>
#                1
#               </span>
#               <span class="pt-li_stats-vote">
#                <i class="material-icons md-18">
#                 add_box
#                </i>
#                0
#               </span>
#              </div>
#             </li>
#             <li class="pt-list-item pt-list-item__no-img">
#              <div class="pt-list-item__title">
#               <h2>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41905802" target="_blank">
#                 <i class="pantip-icons md-18 pt-ic-topic_type_question">
#                 </i>
#                 คิดว่า Evangelion จะมีรีเมคมั้ย
#                </a>
#               </h2>
#               <span>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41905802">
#                </a>
#               </span>
#               <div class="pt-list-item__tag">
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อนิเมะ" target="_blank">
#                 อนิเมะ
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/Evangelion:_3.0+1.01_Thrice_Upon_a_Time_(ภาพยนตร์แอนิเมชัน)" target="_blank">
#                 Evangelion: 3.0+1.01 Thrice Upon a Time (ภาพยนตร์แอนิเมชัน)
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">
#                 อีวานเกเลียน
#                </a>
#               </div>
#              </div>
#              <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41905802" target="_blank">
#               <div class="pt-list-item__img img-thumbnail lazyload" data-bg="">
#               </div>
#              </a>
#              <div class="pt-list-item__info">
#               <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/4125745" target="_blank">
#                <div class="img-thumbnail img-circle" style="background-image:url(https://p.ptcdn.info/296/014/000/4125745_16521468244111_m.jpg)">
#                </div>
#               </a>
#               <h5>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/4125745" target="_blank">
#                 สมาชิกหมายเลข 4125745
#                </a>
#               </h5>
#               <span title="9 มีนาคม 2566 เวลา 04:41 น.">
#                9 มี.ค.
#               </span>
#              </div>
#              <div class="pt-list-item__stats">
#               <span class="pt-li_stats-comment">
#                <i class="material-icons md-18">
#                 message
#                </i>
#                6
#               </span>
#               <span class="pt-li_stats-vote">
#                <i class="material-icons md-18">
#                 add_box
#                </i>
#                0
#               </span>
#              </div>
#             </li>
#             <li class="pt-list-item">
#              <div class="pt-list-item__title">
#               <h2>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41804661" target="_blank">
#                 <i class="pantip-icons md-18 pt-ic-topic_type_review">
#                 </i>
#                 [CR] [รีวิว] Evangelion Wafer Card เก็บครบชุดแล้วโว้ยยยย !!
#                </a>
#               </h2>
#               <span>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41804661">
#                </a>
#               </span>
#               <div class="pt-list-item__tag">
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/Evangelion:_3.0_You_Can_(Not)_Redo" target="_blank">
#                 Evangelion: 3.0 You Can (Not) Redo
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">
#                 อีวานเกเลียน
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน:_ปัจฉิมภาค" target="_blank">
#                 อีวานเกเลียน: ปัจฉิมภาค
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน:_จุติภาค" target="_blank">
#                 อีวานเกเลียน: จุติภาค
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/ของสะสมจากการ์ตูน" target="_blank">
#                 ของสะสมจากการ์ตูน
#                </a>
#               </div>
#              </div>
#              <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41804661" target="_blank">
#               <div class="pt-list-item__img img-thumbnail lazyload" data-bg="https://f.ptcdn.info/451/079/000/rnvbne175xxYNQF0iQj-s.jpg">
#               </div>
#              </a>
#              <div class="pt-list-item__info">
#               <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/1240601" target="_blank">
#                <div class="img-thumbnail img-circle" style="background-image:url(https://p.ptcdn.info/356/003/000/1240601_7319312190_P-Pook-098-JPG_m.jpg)">
#                </div>
#               </a>
#               <h5>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/1240601" target="_blank">
#                 สมาชิกหมายเลข 1240601
#                </a>
#               </h5>
#               <span title="3 มกราคม 2566 เวลา 00:49 น.">
#                3 ม.ค.
#               </span>
#              </div>
#              <div class="pt-list-item__stats">
#               <span class="pt-li_stats-comment">
#                <i class="material-icons md-18">
#                 message
#                </i>
#                3
#               </span>
#               <span class="pt-li_stats-vote">
#                <i class="material-icons md-18">
#                 add_box
#                </i>
#                4
#               </span>
#              </div>
#             </li>
#             <li class="pt-list-item">
#              <div class="pt-list-item__title">
#               <h2>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41671729" target="_blank">
#                 <i class="pantip-icons md-18 pt-ic-topic_type_talking">
#                 </i>
#                 Evangelion: 3.0+1.01 Thrice Upon a Time กำลังจะเข้าฉายบ้านเรา 13 ต.ค.นี้
#                </a>
#               </h2>
#               <span>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41671729">
#                </a>
#               </span>
#               <div class="pt-list-item__tag">
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/โรงภาพยนตร์" target="_blank">
#                 โรงภาพยนตร์
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">
#                 อีวานเกเลียน
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อะนิเมะ" target="_blank">
#                 อะนิเมะ
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/การ์ตูนญี่ปุ่น" target="_blank">
#                 การ์ตูนญี่ปุ่น
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/Evangelion:_3.0_You_Can_(Not)_Redo" target="_blank">
#                 Evangelion: 3.0 You Can (Not) Redo
#                </a>
#               </div>
#              </div>
#              <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41671729" target="_blank">
#               <div class="pt-list-item__img img-thumbnail lazyload" data-bg="https://f.ptcdn.info/675/078/000/rjdmvifmc5ugoHaQFiHq-s.png">
#               </div>
#              </a>
#              <div class="pt-list-item__info">
#               <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/92492" target="_blank">
#                <div class="img-thumbnail img-circle" style="background-image:url(https://p.ptcdn.info/582/011/000/92492_3253243225_Enixma-JABAJA-font_m.jpg)">
#                </div>
#               </a>
#               <h5>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/92492" target="_blank">
#                 Enixma
#                </a>
#               </h5>
#               <span title="7 ตุลาคม 2565 เวลา 16:38 น.">
#                7 ต.ค. 2565
#               </span>
#              </div>
#              <div class="pt-list-item__stats">
#               <span class="pt-li_stats-comment">
#                <i class="material-icons md-18">
#                 message
#                </i>
#                3
#               </span>
#               <span class="pt-li_stats-vote">
#                <i class="material-icons md-18">
#                 add_box
#                </i>
#                1
#               </span>
#              </div>
#             </li>
#             <li class="pt-list-item pt-list-item__no-img">
#              <div class="pt-list-item__title">
#               <h2>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41645625" target="_blank">
#                 <i class="pantip-icons md-18 pt-ic-topic_type_question">
#                 </i>
#                 ตามหาอนิเมะแนวปรัชญาจากโลกอนาคต
#                </a>
#               </h2>
#               <span>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41645625">
#                </a>
#               </span>
#               <div class="pt-list-item__tag">
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/การ์ตูน" target="_blank">
#                 การ์ตูน
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">
#                 อีวานเกเลียน
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อะนิเมะ" target="_blank">
#                 อะนิเมะ
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/การออกแบบ" target="_blank">
#                 การออกแบบ
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/แนะนำการ์ตูน" target="_blank">
#                 แนะนำการ์ตูน
#                </a>
#               </div>
#              </div>
#              <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41645625" target="_blank">
#               <div class="pt-list-item__img img-thumbnail lazyload" data-bg="">
#               </div>
#              </a>
#              <div class="pt-list-item__info">
#               <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/7015798" target="_blank">
#                <div class="img-thumbnail img-circle" style="background-image:url(https://ptcdn.info/images/avatar_member_default.png)">
#                </div>
#               </a>
#               <h5>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/7015798" target="_blank">
#                 สมาชิกหมายเลข 7015798
#                </a>
#               </h5>
#               <span title="22 กันยายน 2565 เวลา 05:06 น.">
#                22 ก.ย. 2565
#               </span>
#              </div>
#              <div class="pt-list-item__stats">
#               <span class="pt-li_stats-comment">
#                <i class="material-icons md-18">
#                 message
#                </i>
#                8
#               </span>
#               <span class="pt-li_stats-vote">
#                <i class="material-icons md-18">
#                 add_box
#                </i>
#                0
#               </span>
#              </div>
#             </li>
#             <li class="pt-list-item">
#              <div class="pt-list-item__title">
#               <h2>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41626510" target="_blank">
#                 <i class="pantip-icons md-18 pt-ic-topic_type_talking">
#                 </i>
#                 สาระสำคัญจาก Neon Genesis Evangelion ตอนที่ 25 – 26 และ Evangelion Death &amp; Rebirth
#                </a>
#               </h2>
#               <span>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41626510">
#                </a>
#               </span>
#               <div class="pt-list-item__tag">
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อนิเมะ" target="_blank">
#                 อนิเมะ
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/การ์ตูนทีวี" target="_blank">
#                 การ์ตูนทีวี
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">
#                 อีวานเกเลียน
#                </a>
# ...
#                <i class="material-icons md-18">
#                 add_box
#                </i>
#                0
#               </span>
#              </div>
#             </li>
#             <li class="pt-list-item pt-list-item__no-img">
#              <div class="pt-list-item__title">
#               <h2>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/40920801" target="_blank">
#                 <i class="pantip-icons md-18 pt-ic-topic_type_talking">
#                 </i>
#                 Evangelion 3.0+1.01 ถามเกี่ยวกับ พ่อของชินจิ (สปอย)
#                </a>
#               </h2>
#               <span>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/40920801">
#                </a>
#               </span>
#               <div class="pt-list-item__tag">
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อนิเมะ" target="_blank">
#                 อนิเมะ
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">
#                 อีวานเกเลียน
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/การ์ตูนญี่ปุ่น" target="_blank">
#                 การ์ตูนญี่ปุ่น
#                </a>
#               </div>
#              </div>
#              <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/40920801" target="_blank">
#               <div class="pt-list-item__img img-thumbnail lazyload" data-bg="">
#               </div>
#              </a>
#              <div class="pt-list-item__info">
#               <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/197307" target="_blank">
#                <div class="img-thumbnail img-circle" style="background-image:url(https://p.ptcdn.info/112/000/000/197307_8560368306_IMG-1036-JPG_m.jpg)">
#                </div>
#               </a>
#               <h5>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/197307" target="_blank">
#                 สวัสดีชาวไทย
#                </a>
#               </h5>
#               <span title="19 สิงหาคม 2564 เวลา 12:57 น.">
#                19 ส.ค. 2564
#               </span>
#              </div>
#              <div class="pt-list-item__stats">
#               <span class="pt-li_stats-comment">
#                <i class="material-icons md-18">
#                 message
#                </i>
#                1
#               </span>
#               <span class="pt-li_stats-vote">
#                <i class="material-icons md-18">
#                 add_box
#                </i>
#                0
#               </span>
#              </div>
#             </li>
#             <li class="pt-list-item pt-list-item__no-img">
#              <div class="pt-list-item__title">
#               <h2>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/40919378" target="_blank">
#                 <i class="pantip-icons md-18 pt-ic-topic_type_question">
#                 </i>
#                 Evagelion 3.0+1.0 อาสึกะ รอดไหมครับ
#                </a>
#               </h2>
#               <span>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/40919378">
#                </a>
#               </span>
#               <div class="pt-list-item__tag">
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/การ์ตูนญี่ปุ่น" target="_blank">
#                 การ์ตูนญี่ปุ่น
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/การ์ตูน" target="_blank">
#                 การ์ตูน
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อนิเมะ" target="_blank">
#                 อนิเมะ
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/Evangelion:_3.0_You_Can_(Not)_Redo" target="_blank">
#                 Evangelion: 3.0 You Can (Not) Redo
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">
#                 อีวานเกเลียน
#                </a>
#               </div>
#              </div>
#              <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/40919378" target="_blank">
#               <div class="pt-list-item__img img-thumbnail lazyload" data-bg="">
#               </div>
#              </a>
#              <div class="pt-list-item__info">
#               <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/6603129" target="_blank">
#                <div class="img-thumbnail img-circle" style="background-image:url(https://ptcdn.info/images/avatar_member_default.png)">
#                </div>
#               </a>
#               <h5>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/6603129" target="_blank">
#                 สมาชิกหมายเลข 6603129
#                </a>
#               </h5>
#               <span title="18 สิงหาคม 2564 เวลา 20:02 น.">
#                18 ส.ค. 2564
#               </span>
#              </div>
#              <div class="pt-list-item__stats">
#               <span class="pt-li_stats-comment">
#                <i class="material-icons md-18">
#                 message
#                </i>
#                2
#               </span>
#               <span class="pt-li_stats-vote">
#                <i class="material-icons md-18">
#                 add_box
#                </i>
#                0
#               </span>
#              </div>
#             </li>
#             <li class="pt-list-item pt-list-item__no-img">
#              <div class="pt-list-item__title">
#               <h2>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/40918245" target="_blank">
#                 <i class="pantip-icons md-18 pt-ic-topic_type_question">
#                 </i>
#                 Evangelion ฉบับมังงะพิมพ์ใหม่ของ sic นี้ยังทำต่ออยู่หรือเปล่าครับ
#                </a>
#               </h2>
#               <span>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/40918245">
#                </a>
#               </span>
#               <div class="pt-list-item__tag">
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">
#                 อีวานเกเลียน
#                </a>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/Evangelion:_3.0_You_Can_(Not)_Redo" target="_blank">
#                 Evangelion: 3.0 You Can (Not) Redo
#                </a>
#               </div>
#              </div>
#              <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/40918245" target="_blank">
#               <div class="pt-list-item__img img-thumbnail lazyload" data-bg="">
#               </div>
#              </a>
#              <div class="pt-list-item__info">
#               <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/4746142" target="_blank">
#                <div class="img-thumbnail img-circle" style="background-image:url(https://ptcdn.info/images/avatar_member_default.png)">
#                </div>
#               </a>
#               <h5>
#                <a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/4746142" target="_blank">
#                 สมาชิกหมายเลข 4746142
#                </a>
#               </h5>
#               <span title="18 สิงหาคม 2564 เวลา 11:17 น.">
#                18 ส.ค. 2564
#               </span>
#              </div>
#              <div class="pt-list-item__stats">
#               <span class="pt-li_stats-comment">
#                <i class="material-icons md-18">
#                 message
#                </i>
#                1
#               </span>
#               <span class="pt-li_stats-vote">
#                <i class="material-icons md-18">
#                 add_box
#                </i>
#                0
#               </span>
#              </div>
#             </li>
#            </ul>
#            <div class="p-all-16 horizontal-top-boder">
#             <div class="flexbox justify-content-center align-items-center">
#              <div>
#               กำลังโหลดข้อมูล
#              </div>
#              <div class="pt-emoji-loading">
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="col-lg-4 pt-lg-toggle-show" id="sidebar-container">
#          <div id="sidebar-fixed">
#           <div class="pt-fixed-line" id="sidebar-last_element">
#           </div>
#           <div class="pt-block pt-block-purple-2 m-b-20">
#            <div class="pt-block-header pt-block-header-purple-1 flex-column">
#             <div class="h6 m-r-12 txt-yellow-700">
#             </div>
#            </div>
#            <div class="pt-loader-oneline">
#             <div class="pt-loader-text pt-loader" style="height:21px">
#             </div>
#            </div>
#            <div class="pt-loader-oneline">
#             <div class="pt-loader-text pt-loader" style="height:21px">
#             </div>
#            </div>
#            <div class="pt-loader-oneline">
#             <div class="pt-loader-text pt-loader" style="height:21px">
#             </div>
#            </div>
#            <div class="pt-loader-oneline">
#             <div class="pt-loader-text pt-loader" style="height:21px">
#             </div>
#            </div>
#            <div class="pt-loader-oneline">
#             <div class="pt-loader-text pt-loader" style="height:21px">
#             </div>
#            </div>
#           </div>
#           <div class="ads_box_type1 m-b-20" id="second-tag-ads" style="display:none">
#            <div id="div-gpt-ad-1569929697239-0" style="width:300px;height:250px">
#             <script>
#              googletag.cmd.push(function() {
# 								    googletag.display('div-gpt-ad-1569929697239-0')
# 								    googletag.pubads().addEventListener('slotRenderEnded', (event) => {
# 								        if (!event.isEmpty) {
#         							        document.getElementById('second-tag-ads').style.display = null
#    								        }
# 								    })
# 							    })
#             </script>
#            </div>
#           </div>
#           <div class="sidebar-footer">
#            <a class="btn btn-success btn-block btn-block m-b-8 gtm-sidebar-footer" href="https://pantip.com/club/190" target="_blank">
#             ข่าวประชาสัมพันธ์
#            </a>
#            <div class="sidebar-bottom">
#             <a class="caption gtm-sidebar-footer" href="https://pantip.com/about/tos" target="_blank">
#              กฎกติกา
#             </a>
#             <a class="caption gtm-sidebar-footer" href="https://pantip.com/advertising" target="_blank">
#              ลงโฆษณา
#             </a>
#             <a class="caption gtm-sidebar-footer" href="https://pantip.com/about/job" target="_blank">
#              สมัครงาน
#             </a>
#             <a class="caption gtm-sidebar-footer" href="https://pantip.com/about/contact" target="_blank">
#              ติดต่อทีมงาน
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"isServer":true,"initialState":{"global":{"baseUrl":"pantip.com","cookies":{"pantip_visitc":"rzoiinhBJD0Bb21Rv","pst":""}},"login":{"isLoggedIn":false,"token":"","member":{"memberId":null,"avatar":null,"nickname":null},"isIncorrectLogin":false},"captcha":{},"profile":{},"maintags":{},"taghits":{},"customizeTagType":{},"header":{"dataDoodle":{"image":{"url":"https://ptcdn.info/doodle/2023/5d07273900d01f33da0f618c_yii66wxtur.png"},"background_image":{"url":"https://ptcdn.info/doodle/2023/5d07273900d01f33da0f618c_tcz28qzvon.png"},"mobile_image":{"url":"https://ptcdn.info/doodle/2023/5d07273900d01f33da0f618c_bkbe0xu94v.png"},"linkUrl":"","hasLink":false,"name":"Pantip.com"},"isDisplayMenuTab":false,"sideNavClass":"","sideNavMaskClass":"","sideNavHomeState":"UNCLICKED","checkMobile":null,"isDisplayUserMenu":false,"showUserMenu":false,"showRoomMenu":false,"showCommunitiesMenu":false,"showSidenavMenu":false,"roomLists":[{"id":100,"name":"รวมมิตร","name_en":"all","slug":"","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-all.svg","description":"รวมกระทู้จากทุกห้อง"},{"id":31,"name":"บางขุนพรหม","name_en":"tvshow","slug":"tvshow","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-tvshow.svg","description":"ละคร นักแสดง ซีรี่ส์ รายการโทรทัศน์ สถานีโทรทัศน์"},{"id":17,"name":"รัชดา","name_en":"ratchada","slug":"ratchada","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-ratchada.svg","description":"รถยนต์ มอเตอร์ไซค์ เครื่องเสียงรถยนต์ แต่งรถ การจราจร"},{"id":13,"name":"บลูแพลนเน็ต","name_en":"blueplanet","slug":"blueplanet","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-blueplanet.svg","description":"เที่ยวไทย เที่ยวต่างประเทศ ทะเล ภูเขา เกาะ น้ำตก ดำน้ำ สายการบิน"},{"id":26,"name":"หว้ากอ","name_en":"wahkor","slug":"wahkor","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-wahkor.svg","description":"วิทยาศาสตร์ วิศวกรรม เทคโนโลยี ฟิสิกส์ ดาราศาสตร์ อวกาศ"},{"id":7,"name":"เฉลิมไทย","name_en":"chalermthai","slug":"chalermthai","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-chalermthai.svg","description":"ภาพยนตร์ ดาราภาพยนตร์ ค่ายหนัง เทศกาลหนัง หนังสั้น"},{"id":33,"name":"พรหมชาติ","name_en":"horoscope","slug":"horoscope","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-horoscope.svg","description":"ดูดวง ฮวงจุ้ย ไพ่ยิปซี ทำนายฝัน พระเครื่อง"},{"id":27,"name":"ห้องสมุด","name_en":"library","slug":"library","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-library.svg","description":"หนังสือ หนังสือนิยาย ภาษาไทย ภาษาจีน ภาษาอังกฤษ ปรัชญา ประวัติศาสตร์"},{"id":1,"name":"กล้อง","name_en":"camera","slug":"camera","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-camera.svg","description":"กล้องถ่ายรูป กล้อง DSLR กล้องวิดีโอ เทคนิคการถ่ายรูป"},{"id":36,"name":"แก็ดเจ็ต","name_en":"gadget","slug":"gadget","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-gadget.svg","description":"Gadget, Action Camera, Drone, Game Console, Smartwatch, Smartband"},{"id":6,"name":"เฉลิมกรุง","name_en":"chalermkrung","slug":"chalermkrung","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-chalermkrung.svg","description":"นักร้องนักดนตรี เพลง เครื่องดนตรี คอนเสิร์ต มิวสิควิดีโอ"},{"id":99,"name":"ไร้สังกัด","name_en":"isolate","slug":"isolate","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-isolate.svg","description":"กระทู้อื่นๆ ที่ไม่สังกัดห้องไหนเลย"},{"id":11,"name":"โต๊ะเครื่องแป้ง","name_en":"beauty","slug":"beauty","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-beauty.svg","description":"เครื่องสำอาง เสริมสวย แฟชั่น เครื่องประดับ ลดความอ้วน"},{"id":28,"name":"กรีนโซน","name_en":"greenzone","slug":"greenzone","is_pinned":false,"imageUrl":"https://ptcdn.info/mobile/icon_room/pt-forum-greenzone.svg","description":" ...
#   </script>
#  </body>
# </html>

# %%
#ดึงข้อมูลที่ต้องการ
#movie_containers = page_html.find_all('ul', class_='pt-list pt-list-item__full-title pt-list__type-a')
movie_containers = page_html.find_all('li', class_='pt-list-item pt-list-item__no-img')
links = []
subjects = []
members = [] # หมายเลข member เช่น  6739396

# %%
print(movie_containers)
# Out:
# [<li class="pt-list-item pt-list-item__no-img"><div class="pt-list-item__title"><h2><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/42003778" target="_blank"><i class="pantip-icons md-18 pt-ic-topic_type_question"></i>อยากรู้ว่าทำไมชินจิกับอาซึกะถึงใส่ห่วงคอสีดำหรอคะ ?</a></h2><span><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/42003778"></a></span><div class="pt-list-item__tag"><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">อีวานเกเลียน</a></div></div><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/42003778" target="_blank"><div class="pt-list-item__img img-thumbnail lazyload" data-bg=""></div></a><div class="pt-list-item__info"><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/6739096" target="_blank"><div class="img-thumbnail img-circle" style="background-image:url(https://ptcdn.info/images/avatar_member_default.png)"></div></a><h5><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/6739096" target="_blank">สมาชิกหมายเลข 6739096</a></h5><span title="7 พฤษภาคม 2566 เวลา 20:12 น.">7 พ.ค.</span></div><div class="pt-list-item__stats"><span class="pt-li_stats-comment"><i class="material-icons md-18">message</i>0</span><span class="pt-li_stats-vote"><i class="material-icons md-18">add_box</i>0</span></div></li>, <li class="pt-list-item pt-list-item__no-img"><div class="pt-list-item__title"><h2><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41960388" target="_blank"><i class="pantip-icons md-18 pt-ic-topic_type_question"></i>สรุปแล้วคุณมิซาโตะตายจริงหรอครับ?</a></h2><span><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41960388"></a></span><div class="pt-list-item__tag"><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อีวานเกเลียน" target="_blank">อีวานเกเลียน</a></div></div><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41960388" target="_blank"><div class="pt-list-item__img img-thumbnail lazyload" data-bg=""></div></a><div class="pt-list-item__info"><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/7503951" target="_blank"><div class="img-thumbnail img-circle" style="background-image:url(https://ptcdn.info/images/avatar_member_default.png)"></div></a><h5><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/profile/7503951" target="_blank">สมาชิกหมายเลข 7503951</a></h5><span title="10 เมษายน 2566 เวลา 23:01 น.">10 เม.ย.</span></div><div class="pt-list-item__stats"><span class="pt-li_stats-comment"><i class="material-icons md-18">message</i>0</span><span class="pt-li_stats-vote"><i class="material-icons md-18">add_box</i>0</span></div></li>, <li class="pt-list-item pt-list-item__no-img"><div class="pt-list-item__title"><h2><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41905802" target="_blank"><i class="pantip-icons md-18 pt-ic-topic_type_question"></i>คิดว่า Evangelion จะมีรีเมคมั้ย</a></h2><span><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="https://pantip.com/topic/41905802"></a></span><div class="pt-list-item__tag"><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/อนิเมะ" target="_blank">อนิเมะ</a><a class="gtm-latest-topic gtm-topic-layout-compact gtm-topic-type-filter-all" href="/tag/Evangelion:_3.0+1.01_Thrice_Upon_a_Time_(ภาพยนตร์แอนิเมชัน)" target="_blank">Evangelion: 3.0 ...

# %%
# For every movie of these 50
for container in movie_containers:
    # Scrape the name
    link = container.h2.a["href"]
    links.append(link)
    subject = container.h2.a.get_text(strip=True)
    subjects.append(subject)
    member = container.h5.a.get_text(strip=True)
    members.append(member)

# %%
subjects
# Out:
# ['อยากรู้ว่าทำไมชินจิกับอาซึกะถึงใส่ห่วงคอสีดำหรอคะ ?',
#  'สรุปแล้วคุณมิซาโตะตายจริงหรอครับ?',
#  'คิดว่า Evangelion จะมีรีเมคมั้ย',
#  'ตามหาอนิเมะแนวปรัชญาจากโลกอนาคต',
#  'Evangelion',
#  'ดูneon genesis evangelionพากย์\u200bไทยแบบถูกลิขสิทธิ์ไดที่ไหน',
#  'ตอนจบของ Rebuild of Evangelion',
#  'คำถามเกี่ยวกับ Evangelion???',
#  'สอบถามถึงสถานที่ในEvagelionค่ะ',
#  '10หนังทำเงินสูงสุดในญี่ปุ่น',
#  'สิ่งที่อยู่บนหัวของนักบินอีวาในเรื่องเอวาเกเลี่ยนเรียกว่าอะไร?',
#  '[Evangelion]ใครคือคนรักของชินจิกันแน่',
#  'evangelion มีภาคไหนที่คาโอรุไม่ตาย',
#  'shinkalion X evangelion มารวมกันได้ไงครับ',
#  'สอบถามเพื่อนๆ ที่รอดู/เก็บ Evangelion 3.0+1.01 Thrice Upon a Time แบบถูกลิขสิทธิ์หน่อยครับ',
#  'คำถามงงๆ Evangelion',
#  '[CR] [รีวิว] Asuka Resin 1/4 XZ Studio',
#  'หาเพลงใน evangelion ครับ',
#  'Evangelion รีปริ้นเล่ม 11-14 จะมาไหมครับหรือไม่มา',
#  'ตามหาเกม(PC)ที่เคยเล่นสมัยเด็กๆ นึกชื่อไม่ออกจริงๆครับ ช่วยผมหน่อยครับ',
#  '[CR] [รีวิว] Medicom 400% + 100% Bearbrick ~ Evangelion: Destruction Be@rbrick EVA Unit 02',
#  'สอบถามเรื่องของแม่ ริสสึโกะ ใน evangelion หน่อยครับ',
#  'สงสัยเรื่องความสัมพันธ์ระหว่าง อาคางิ ริทสึโกะ - อิคาริ เก็นโด',
#  'Evangelion 3.0+1.01 ทำให้อึนมาก',
#  'Evangelion 01และชินจิ มีความสำคัญอะไรในพิธีน้ำส้ม?',
#  'ใครดู Evangelion 3.0+1.01 จบแล้วรู้เรื่อง ช่วยอธิบายทีได้มั้ยครับ',
#  'Evangelion 3.0+1.01',
#  'evangelion 3.0+1.0 เรย์ในปล๊ก',
#  'หลังดู Evangelion 3.0+1.0แล้วมีคําถาม',
#  'rebuild fo evangelion จะมีภาคแยกหลักจากจบภาค 3.0+1.01 ไหม??',
#  'Evangelion 3.0+1.01 ถามเกี่ยวกับ พ่อของชินจิ (สปอย)',
#  'Evagelion 3.0+1.0 อาสึกะ รอดไหมครับ',
#  'Evangelion ฉบับมังงะพิมพ์ใหม่ของ sic นี้ยังทำต่ออยู่หรือเปล่าครับ']

# %%
members
# Out:
# ['สมาชิกหมายเลข 6739096',
#  'สมาชิกหมายเลข 7503951',
#  'สมาชิกหมายเลข 4125745',
#  'สมาชิกหมายเลข 7015798',
#  'สมาชิกหมายเลข 6553144',
#  'สมาชิกหมายเลข 6610133',
#  'สมาชิกหมายเลข 6937247',
#  'สมาชิกหมายเลข 6543821',
#  'สมาชิกหมายเลข 6768033',
#  'สมาชิกหมายเลข 1173954',
#  'สมาชิกหมายเลข 6768033',
#  'สมาชิกหมายเลข 4411761',
#  'สมาชิกหมายเลข 4993551',
#  'สมาชิกหมายเลข 4732759',
#  'zailnez',
#  'สมาชิกหมายเลข 4732759',
#  'สมาชิกหมายเลข 1240601',
#  'สมาชิกหมายเลข 4732759',
#  'สมาชิกหมายเลข 5560882',
#  'นังหน้ามักคะลีนอย',
#  'สมาชิกหมายเลข 1240601',
#  'สมาชิกหมายเลข 4031693',
#  'สมาชิกหมายเลข 6561191',
#  'สมาชิกหมายเลข 3857989',
#  'สมาชิกหมายเลข 6583909',
#  'สมาชิกหมายเลข 5019311',
#  'สมาชิกหมายเลข 4529238',
#  'สมาชิกหมายเลข 6608649',
#  'สมาชิกหมายเลข 5636160',
#  'สมาชิกหมายเลข 6606302',
#  'สวัสดีชาวไทย',
#  'สมาชิกหมายเลข 6603129',
#  'สมาชิกหมายเลข 4746142']

# %%
links
# Out:
# ['https://pantip.com/topic/42003778',
#  'https://pantip.com/topic/41960388',
#  'https://pantip.com/topic/41905802',
#  'https://pantip.com/topic/41645625',
#  'https://pantip.com/topic/41615503',
#  'https://pantip.com/topic/41396249',
#  'https://pantip.com/topic/41327242',
#  'https://pantip.com/topic/41284193',
#  'https://pantip.com/topic/41271380',
#  'https://pantip.com/topic/41247113',
#  'https://pantip.com/topic/41222749',
#  'https://pantip.com/topic/41187159',
#  'https://pantip.com/topic/41181393',
#  'https://pantip.com/topic/41151663',
#  'https://pantip.com/topic/41112233',
#  'https://pantip.com/topic/41111850',
#  'https://pantip.com/topic/41107900',
#  'https://pantip.com/topic/41105496',
#  'https://pantip.com/topic/41089525',
#  'https://pantip.com/topic/41071091',
#  'https://pantip.com/topic/41039291',
#  'https://pantip.com/topic/40978373',
#  'https://pantip.com/topic/40958712',
#  'https://pantip.com/topic/40955953',
#  'https://pantip.com/topic/40951943',
#  'https://pantip.com/topic/40931330',
#  'https://pantip.com/topic/40928775',
#  'https://pantip.com/topic/40926738',
#  'https://pantip.com/topic/40923991',
#  'https://pantip.com/topic/40923604',
#  'https://pantip.com/topic/40920801',
#  'https://pantip.com/topic/40919378',
#  'https://pantip.com/topic/40918245']

# %%
pantip_df = pd.DataFrame({
    'subject': subjects,
    'surl': links,
    'member':members,
})

# %%
pantip_df
# Out:
#                                               subject  \
# 0   อยากรู้ว่าทำไมชินจิกับอาซึกะถึงใส่ห่วงคอสีดำหร...
# 1                   สรุปแล้วคุณมิซาโตะตายจริงหรอครับ?
# 2                     คิดว่า Evangelion จะมีรีเมคมั้ย
# 3                     ตามหาอนิเมะแนวปรัชญาจากโลกอนาคต
# 4                                          Evangelion
# 5   ดูneon genesis evangelionพากย์​ไทยแบบถูกลิขสิท...
# 6                      ตอนจบของ Rebuild of Evangelion
# 7                        คำถามเกี่ยวกับ Evangelion???
# 8                      สอบถามถึงสถานที่ในEvagelionค่ะ
# 9                         10หนังทำเงินสูงสุดในญี่ปุ่น
# 10  สิ่งที่อยู่บนหัวของนักบินอีวาในเรื่องเอวาเกเลี...
# 11              [Evangelion]ใครคือคนรักของชินจิกันแน่
# 12                 evangelion มีภาคไหนที่คาโอรุไม่ตาย
# 13          shinkalion X evangelion มารวมกันได้ไงครับ
# 14  สอบถามเพื่อนๆ ที่รอดู/เก็บ Evangelion 3.0+1.01...
# 15                                คำถามงงๆ Evangelion
# 16             [CR] [รีวิว] Asuka Resin 1/4 XZ Studio
# 17                           หาเพลงใน evangelion ครับ
# 18  Evangelion รีปริ้นเล่ม 11-14 จะมาไหมครับหรือไม่มา
# 19  ตามหาเกม(PC)ที่เคยเล่นสมัยเด็กๆ นึกชื่อไม่ออกจ...
# 20  [CR] [รีวิว] Medicom 400% + 100% Bearbrick ~ E...
# 21  สอบถามเรื่องของแม่ ริสสึโกะ ใน evangelion หน่อ...
# 22  สงสัยเรื่องความสัมพันธ์ระหว่าง อาคางิ ริทสึโกะ...
# 23                    Evangelion 3.0+1.01 ทำให้อึนมาก
# 24  Evangelion 01และชินจิ มีความสำคัญอะไรในพิธีน้ำ...
# 25  ใครดู Evangelion 3.0+1.01 จบแล้วรู้เรื่อง ช่วย...
# 26                                Evangelion 3.0+1.01
# 27                      evangelion 3.0+1.0 เรย์ในปล๊ก
# 28              หลังดู Evangelion 3.0+1.0แล้วมีคําถาม
# 29  rebuild fo evangelion จะมีภาคแยกหลักจากจบภาค 3...
# 30  Evangelion 3.0+1.01 ถามเกี่ยวกับ พ่อของชินจิ (...
# 31                Evagelion 3.0+1.0 อาสึกะ รอดไหมครับ
# 32  Evangelion ฉบับมังงะพิมพ์ใหม่ของ sic นี้ยังทำต...
#
#                                  surl                 member
# 0   https://pantip.com/topic/42003778  สมาชิกหมายเลข 6739096
# 1   https://pantip.com/topic/41960388  สมาชิกหมายเลข 7503951
# 2   https://pantip.com/topic/41905802  สมาชิกหมายเลข 4125745
# 3   https://pantip.com/topic/41645625  สมาชิกหมายเลข 7015798
# 4   https://pantip.com/topic/41615503  สมาชิกหมายเลข 6553144
# 5   https://pantip.com/topic/41396249  สมาชิกหมายเลข 6610133
# 6   https://pantip.com/topic/41327242  สมาชิกหมายเลข 6937247
# 7   https://pantip.com/topic/41284193  สมาชิกหมายเลข 6543821
# 8   https://pantip.com/topic/41271380  สมาชิกหมายเลข 6768033
# 9   https://pantip.com/topic/41247113  สมาชิกหมายเลข 1173954
# 10  https://pantip.com/topic/41222749  สมาชิกหมายเลข 6768033
# 11  https://pantip.com/topic/41187159  สมาชิกหมายเลข 4411761
# 12  https://pantip.com/topic/41181393  สมาชิกหมายเลข 4993551
# 13  https://pantip.com/topic/41151663  สมาชิกหมายเลข 4732759
# 14  https://pantip.com/topic/41112233                zailnez
# 15  https://pantip.com/topic/41111850  สมาชิกหมายเลข 4732759
# 16  https://pantip.com/topic/41107900  สมาชิกหมายเลข 1240601
# 17  https://pantip.com/topic/41105496  สมาชิกหมายเลข 4732759
# 18  https://pantip.com/topic/41089525  สมาชิกหมายเลข 5560882
# 19  https://pantip.com/topic/41071091      นังหน้ามักคะลีนอย
# 20  https://pantip.com/topic/41039291  สมาชิกหมายเลข 1240601
# 21  https://pantip.com/topic/40978373  สมาชิกหมายเลข 4031693
# 22  https://pantip.com/topic/40958712  สมาชิกหมายเลข 6561191
# 23  https://pantip.com/topic/40955953  สมาชิกหมายเลข 3857989
# 24  https://pantip.com/topic/40951943  สมาชิกหมายเลข 6583909
# 25  https://pantip.com/topic/40931330  สมาชิกหมายเลข 5019311
# 26  https://pantip.com/topic/40928775  สมาชิกหมายเลข 4529238
# 27  https://pantip.com/topic/40926738  สมาชิกหมายเลข 6608649
# 28  https://pantip.com/topic/40923991  สมาชิกหมายเลข 5636160
# 29  https://pantip.com/topic/40923604  สมาชิกหมายเลข 6606302
# 30  https://pantip.com/topic/40920801           สวัสดีชาวไทย
# 31  https://pantip.com/topic/40919378  สมาชิกหมายเลข 6603129
# 32  https://pantip.com/topic/40918245  สมาชิกหมายเลข 4746142

# %%
pantip_df.to_csv('pantip_data.csv')
