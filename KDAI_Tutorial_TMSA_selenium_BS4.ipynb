# %% [markdown]
# <a href="https://colab.research.google.com/github/Pongpang-2102/Text_Mining_and_Sentiment_Analytics_KDAI_projects/blob/main/KDAI_Tutorial_TMSA_selenium_BS4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install webdriver_manager
# !pip install selenium

# %%
pip install undetected-chromedriver

# %%
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import urllib.request
import undetected_chromedriver as uc

try:
    service = Service(ChromeDriverManager().install())
except ValueError:
    latest_chromedriver_version_url = "https://chromedriver.storage.googleapis.com/LATEST_RELEASE"
    latest_chromedriver_version = urllib.request.urlopen(latest_chromedriver_version_url).read().decode('utf-8')
    service = Service(ChromeDriverManager(version=latest_chromedriver_version).install())
driver_executable_path = service.path

options = uc.ChromeOptions()

# %%
from selenium import webdriver

URL = "https://twitter.com/Sanook"

options = webdriver.ChromeOptions()
options.add_argument("--headless")
options.add_argument('--disable-dev-shm-usage')
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(
    options=options
)

driver.get(URL)
title = driver.title


print(title)

# %%
from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# %%
soup.find(attrs={"data-testid": "UserDescription"}).text
# Out:
# 'ครบทุกเรื่องเพื่อทุกคน'

# %%
# solution
followers = soup.find(attrs = {"href": "/Sanook/followers"}).find_all('span')[1].text
location = soup.find(attrs={"data-testid": "UserProfileHeader_Items"}).find_all('span')[1].text
join_date = soup.find(attrs = {"data-testid": "UserJoinDate"}).find_all('span')[0].text

print(f"Followers: {followers} \nLocation: {location} \nJoin date: {join_date}")
# Out:
# Followers: 259K
# Location: Entertainment & Recreation
# Join date: Joined March 2009

# %%
for i in soup.find_all('div', attrs={"class": "css-1dbjc4n"}):
#เอาเฉพาะ div class ที่ต้องการ
  print(i.get_text())
# Out:
# Don’t miss what’s happeningPeople on Twitter are the first to know.Log inSign upSanook.com462.5K postsSee new TweetsFollowClick to Follow SanookSanook.com@Sanookครบทุกเรื่องเพื่อทุกคนTranslate bioEntertainment & RecreationBangkok, Thailandsanook.comJoined March 2009768 Following259K FollowersPostsAffiliatesRepliesMediaLikesSanook.com’s TweetsSanook.com@Sanook·Jul 1, 2020ผู้ชนะรางวัล Social Superstar ซุปตาร์แห่งโลกโซเชียล ในงาน #JTMA2020 ได้แก่ แบมแบม-กันต์พิมุกต์ ภูวกุล หรือ แบมแบม #GOT7 @BamBam1A
# #JOOXThailandMusicAwards2020
# #SanookxJTMA2020BamBam and 2 others56720.4K41.2KSanook.com@Sanook·Sep 16, 2020หนุ่มๆ วง Stray Kids ส่งคลิปมาเซย์ไฮกับแฟนๆ STAY ชาวสนุกโดยเฉพาะ แสนจะเจื้อแจ้วน่ารัก อย่าลืมฟังอัลบั้ม The 1st Album Repackage ‘IN生 (IN LIFE)’ กันเยอะๆ นะ
# รายละเอียดอัลบั้ม http://sanook.com/music/2424361
# @Stray_Kids @JYPTHAILAND
# ...

# %%
driver.close()
